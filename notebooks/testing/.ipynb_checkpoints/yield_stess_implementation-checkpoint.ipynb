# %%
import sys

sys.path.insert(0,"../../src")
from numba import njit

import numpy as np
import hoomd
from hoomd import md
import helper
import potentials
import protocols
import importlib
import ex_render

# %%
context = hoomd.context.initialize("--mode=cpu")
# Out:
# HOOMD-blue 2.9.0 DOUBLE HPMC_MIXED TBB SSE SSE2 SSE3
# Compiled: 02/04/2020
# Copyright (c) 2009-2019 The Regents of the University of Michigan.
# -----
# You are using HOOMD-blue. Please cite the following:
# * J A Anderson, C D Lorenz, and A Travesset. "General purpose molecular dynamics
#   simulations fully implemented on graphics processing units", Journal of
#   Computational Physics 227 (2008) 5342--5359
# * J Glaser, T D Nguyen, J A Anderson, P Lui, F Spiga, J A Millan, D C Morse, and
#   S C Glotzer. "Strong scaling of general-purpose molecular dynamics simulations
#   on GPUs", Computer Physics Communications 192 (2015) 97--107
# -----
# HOOMD-blue is running on the CPU

# %%
system, snap = protocols.prepare_HTL(500, 0.9, 0)
# Out:
# notice(2): Group "all" created containing 500 particles
# notice(2): -- Neighborlist exclusion statistics -- :
# notice(2): Particles with 0 exclusions             : 500
# notice(2): Neighbors included by diameter          : no
# notice(2): Neighbors excluded when in the same body: no
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
ys = protocols.find_yield_stress_distribution(system, snap)
# Out:
# 24 27
# <class 'numpy.ndarray'> (51, 2)
# 51 27
# [-0.9081762  4.938577 ]
# <hoomd._hoomd.SnapshotSystemData_float object at 0x7f5dfa7e1d70>
# notice(2): Group "all" created containing 51 particles
# notice(2): Group "tags 0-23" created containing 24 particles
# [[0, 0], [1000000, 0.1]]
# notice(2): -- Neighborlist exclusion statistics -- :
# notice(2): Particles with 0 exclusions             : 51
# notice(2): Neighbors included by diameter          : no
# notice(2): Neighbors excluded when in the same body: no
# 1001 10 0.0009 -3.187826778452136e-05
# 1001 20 0.0019 -3.725906858308998e-05
# 1001 30 0.0029000000000000002 -4.264793522834461e-05
# 1001 40 0.0039000000000000003 -4.803782794282359e-05
# 1001 50 0.004900000000000001 -5.342594907016913e-05
# 1001 60 0.0059 -5.880485809546049e-05
# 1001 70 0.006900000000000001 -6.418726574992875e-05
# 1001 80 0.0079 -6.956405738957871e-05
# 1001 90 0.0089 -7.492988069611238e-05
# 1001 100 0.0099 -8.030207222372597e-05
# 1001 110 0.0109 -8.564840783157133e-05
# 1001 120 0.0119 -9.100648318834421e-05
# 1001 130 0.012900000000000002 -9.63395123267266e-05
# 1001 140 0.013900000000000003 -0.0001016755588964838
# 1001 150 0.0149 -0.00010699151911138936
# 1001 160 0.0159 -0.00011230178842933474
# 1001 170 0.016900000000000002 -0.00011758996942783793
# 1001 180 0.0179 -0.00012287143149225716
# 1001 190 0.0189 -0.00012813167681905338
# 1001 200 0.0199 -0.00013337696456979043
# 1001 210 0.020900000000000002 -0.00013860117890352936
# 1001 220 0.021900000000000003 -0.00014380494340359454
# 1001 230 0.022900000000000004 -0.00014898492338970393
# 1001 240 0.0239 -0.00015413720814423142
# 1001 250 0.024900000000000002 -0.00015925014945774126
# 1001 260 0.025900000000000003 -0.0001643364727197145
# 1001 270 0.026900000000000004 -0.0001693749991997398
# 1001 280 0.027900000000000005 -0.0001743770522290058
# 1001 290 0.0289 -0.0001793625755434573
# 1001 300 0.0299 -0.0001843027843188034
# 1001 310 0.0309 -0.00018922699677863144
# 1001 320 0.031900000000000005 -0.00019413096595291568
# 1001 330 0.032900000000000006 -0.00019902391102718337
# 1001 340 0.033900000000000007 -0.0002038943864167413
# 1001 350 0.0349 -0.00020875939102106209
# 1001 360 0.0359 -0.00021359772029849746
# 1001 370 0.0369 -0.00021841602921637317
# 1001 380 0.0379 -0.00022321044639325417
# 1001 390 0.038900000000000004 -0.0002279872764486282
# 1001 400 0.039900000000000005 -0.00023272485375201075
# 1001 410 0.0409 -0.00023744252315445916
# 1001 420 0.0419 -0.00024211123680609712
# 1001 430 0.0429 -0.0002467548205878122
# 1001 440 0.0439 -0.00025137776842968404
# 1001 450 0.0449 -0.00025596583317079807
# 1001 460 0.0459 -0.0002605477857032794
# 1001 470 0.0469 -0.000265086282501859
# 1001 480 0.0479 -0.0002696126221023819
# 1001 490 0.0489 -0.00027409535877133103
-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-69809a44bd08> in <module>
# ----> 1 ys = protocols.find_yield_stress_distribution(system, snap)
#
# ~/Documents/Projects/hoomd_prod/src/protocols.py in find_yield_stress_distribution(system, snapshot, R1, R2, potential)
#     189         tsnap.particles.velocity[:] = np.zeros_like(tsnap.particles.velocity[:])
#     190         tsnap.particles.typeid[:] = typ
# --> 191         yield_stress = yield_stress_routine(system, tsnap, len(N1), len(N2), potential=potential, dump=f"0_{i}")
#     192         yield_stresses.append(yield_stress)
#     193         break
#
# ~/Documents/Projects/hoomd_prod/src/protocols.py in yield_stress_routine(system, snapshot, N1, N2, potential, dump)
#     122             fire.reset()
#     123             while not(fire.has_converged()):
# --> 124                 hoomd.run(1000,quiet=True)
#     125                 idx += 1
#     126             stress.append(log.query('pressure_xy'))
#
# ~/anaconda3/envs/memory/lib/python3.8/site-packages/hoomd/__init__.py in run(tsteps, profile, limit_hours, limit_multiple, callback_period, callback, quiet)
#     173         context.msg.warning("Starting a run without an integrator set");
#     174     else:
# --> 175         context.current.integrator.update_forces();
#     176         context.current.integrator.update_methods();
#     177         context.current.integrator.update_thermos();
#
# ~/anaconda3/envs/memory/lib/python3.8/site-packages/hoomd/integrate.py in update_forces(self)
#     112
#     113             if f.log or f.enabled:
# --> 114                 f.update_coeffs();
#     115
#     116             if f.enabled:
#
# ~/anaconda3/envs/memory/lib/python3.8/site-packages/hoomd/md/pair.py in update_coeffs(self)
#    1163                 coeff = self.pair_coeff.get(type_list[i], type_list[j], "coeff");
#    1164
# -> 1165                 self.update_pair_table(i, j, func, rmin, rmax, coeff);
#    1166
#    1167     def set_from_file(self, a, b, filename):
#
# ~/anaconda3/envs/memory/lib/python3.8/site-packages/hoomd/md/pair.py in update_pair_table(self, typei, typej, func, rmin, rmax, coeff)
#    1093         for i in range(0, self.width):
#    1094             r = rmin + dr * i;
# -> 1095             (V,F) = func(r, rmin, rmax, **coeff);
#    1096
#    1097             # fill out the tables
#
# ~/Documents/Projects/hoomd_prod/src/potentials.py in hertz(r, rmin, rmax, sigma)
#      38
#      39 def hertz(r, rmin, rmax, sigma):
# ---> 40         V = 0.4*np.power(1-r/sigma, 2.5)
#      41         F = (1/sigma)*np.power(1-r/sigma, 1.5)
#      42         return (V, F)
#
# KeyboardInterrupt:

# %%
importlib.reload(protocols)
# Out:
# <module 'protocols' from '../../src/protocols.py'>

# %%
test_dir = "../../test"

# %%
import glob
import gsd
import pandas as pd

# %%
trajs = glob.glob(test_dir+"/traj*")

# %%
trajs
# Out:
# ['../../test/traj_0_0_0.0000.gsd',
#  '../../test/traj_0_0_0.2618.gsd',
#  '../../test/traj_0_0_0.1745.gsd',
#  '../../test/traj_0_0_0.0873.gsd']

# %%
ex_render.display_movie(ex_render.render_disk_frame, trajs[0])

# %%
f = gsd.hoomd.open(trajs[0])

# %%
f.file.nframes
# Out:
# 2

# %%
logs = glob.glob(test_dir+"/log*")

# %%
df = pd.read_csv(logs[0], sep='\t')

# %%
df.pressure_xy.plot()
