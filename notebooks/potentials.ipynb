# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def dipole_force(x):
    return 1/x**4

# %%
x = np.linspace(100,101,1000)
y = dipole_force(x)
plt.plot(x, y)
#plt.yscale('log')
#plt.xscale('log')
