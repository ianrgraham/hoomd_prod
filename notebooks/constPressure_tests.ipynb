# %%
import gsd.hoomd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import glob
import pandas as pd

# %%
def phi_to_L(phi=0.9,N=16000):
    return np.power(0.5*N*np.pi*((5/12)**2 + (7/12)**2)/phi,1/2) 

def L_to_phi(L, N=16000):
    return 0.5*N*np.pi*((5/12)**2 + (7/12)**2)/L**2

# %%
dirs= glob.glob("../test_data/constPressure0.001_N2048_seed*")

# %%
file = dirs[0] + "/log.dat"
df = pd.read_csv(file, delimiter='\t')

# %%
traj = file.replace("log.dat","traj.gsd")
f = gsd.hoomd.open(name=traj, mode="rb")
s = f[0]

# %%
L = s.configuration.box[0]

# %%
L_to_phi(L, N=2048)
# Out:
# 0.8611221404308907

# %%
df["potential_energy"].iloc[5:40000:4000].plot()

# %%
df["xy"].iloc[0:40000:2000].plot()
